# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
# brent = yf.download("BZ=F", start="2007-01-01", end="2024-12-31")
plt.plot(brent[("Close", "BZ=F")])
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
close = brent[("Close", "BZ=F")]

# %%
missing_ids = np.random.choice(len(close), replace=False, size=200)
true_missing = close[missing_ids]
# Out:
# /tmp/ipykernel_3664459/2801374558.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   true_missing = close[missing_ids]

# %%
close.iloc[missing_ids] = np.nan
# Out:
# /tmp/ipykernel_3664459/4124047604.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   close.iloc[missing_ids] = np.nan

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
close_filled = close.ffill()

# %%
mean_absolute_percentage_error(true_missing, close_filled[missing_ids])
# Out:
# /tmp/ipykernel_3664459/2392000378.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mean_absolute_percentage_error(true_missing, close_filled[missing_ids])
# 0.01604858316888621
